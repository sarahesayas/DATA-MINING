# %% [markdown]
# # Week 2, Lab 1: Data Understanding

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset

df=pd.read_csv('income.csv')
df.head()
# Out:
#    ID  Age     Income  Height  Credit Score        Dept    Country Occupation  \
# 0   1   62    50000.0   193.0         509.0  488.563060         UK    Teacher
# 1   2   65  1000000.0   187.0         316.0  312.467648    Germany     Doctor
# 2   3   18   150000.0   178.0         406.0  387.337992  Australia     Artist
# 3   4   -2   200000.0   197.0         464.0  678.652685     France     Artist
# 4   5   21   200000.0   190.0         836.0  411.977741      Japan     Lawyer
#
#   Date of Joining
# 0       7/14/2023
# 1       12/1/2023
# 2       6/20/2022
# 3       3/28/2023
# 4       5/19/2022

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Income', 'Height', 'Credit Score', 'Dept', 'Country',
#        'Occupation', 'Date of Joining'],
#       dtype='object')

# %%
dataset_size = df.shape
print('Dataset Size:', dataset_size)
# Out:
# Dataset Size: (100, 9)

# %% [markdown]
# ***So we have 100 people (rows), and 9 columns***

# %%
df.describe()
# Out:
#                ID        Age          Income      Height  Credit Score  \
# count  100.000000  100.00000       80.000000   95.000000     95.000000
# mean    50.500000   40.55000   232812.500000  176.421053    572.442105
# std     29.011492   26.89312   291936.836143   14.022458    154.830018
# min      1.000000   -9.00000    20000.000000  150.000000    304.000000
# 25%     25.750000   25.50000    50000.000000  167.000000    438.000000
# 50%     50.500000   38.00000   100000.000000  178.000000    580.000000
# 75%     75.250000   56.00000   200000.000000  188.000000    703.500000
# max    100.000000  164.00000  1000000.000000  199.000000    842.000000
#
#               Dept
# count   100.000000
# mean    529.379719
# std     328.055716
# min     -21.788330
# 25%     353.835110
# 50%     494.493787
# 75%     637.867770
# max    2500.439764

# %% [markdown]
# Some takeaways:
# + Not all *incomes*, *heights*, and *credit scores* have been inputted
# + Mean age is 40, mean income is $232,812
# + Std of Income looks pretty weird
# + Youngest person is -9 years old?
# + Oldest person here is 164 years old?

# %% [markdown]
# Lets check the categorical variables, which would be **Country** and **Occupation**

# %%
df['Country'].unique()
# This will look at the COUNTRY column, and see the variables with no repeat
# Out:
# array(['UK', 'Germany', 'Australia', 'France', 'Japan', 'Canada', 'USA',
#        'U.S.', 'India'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array(['Teacher', 'Doctor', 'Artist', 'Lawyer', 'Artxst', 'Engxneer',
#        'Nurse', 'Engineer', 'Docxor', 'Teaxher'], dtype=object)

# %% [markdown]
# Note that we have some mispellings. There's **2 different doctors**, **2 artists**, **2 engineers**, **2 teachers** due to misspelling.

# %% [markdown]
# # Understanding the Distribution
# Create a for-loop to count the values for the categorical variables

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"Value of {col}: \n{df[col].value_counts()}\n")
# Out:
# Value of Country:
# Country
# Australia    17
# France       13
# Germany      12
# Canada       12
# U.S.         10
# UK            9
# Japan         9
# USA           9
# India         9
# Name: count, dtype: int64
#
# Value of Occupation:
# Occupation
# Nurse       24
# Artist      17
# Teacher     15
# Engineer    14
# Lawyer      14
# Doctor      11
# Artxst       2
# Engxneer     1
# Docxor       1
# Teaxher      1
# Name: count, dtype: int64
#
# Value of Date of Joining:
# Date of Joining
# 10/6/2023     2
# 5/14/2023     2
# 10/27/2023    2
# 2/14/2023     2
# 6/30/2022     1
#              ..
# 2/16/2022     1
# 5/16/2022     1
# 4/8/2023      1
# 11/5/2023     1
# 4/26/2022     1
# Name: count, Length: 96, dtype: int64

# %% [markdown]
# A few things to note here:
# + There's only 5 misspelled occupations
# + "Date of Joining" has been considered an "object" (categorical) datatype, when it is a date/time datatype

# %% [markdown]
# ### Let's check the data types

# %%
data_types=df.dtypes
print(data_types)
# Out:
# ID                   int64
# Age                  int64
# Income             float64
# Height             float64
# Credit Score       float64
# Dept               float64
# Country             object
# Occupation          object
# Date of Joining     object
# dtype: object

# %% [markdown]
# Let's convert "Date of Joining" variable to a datetime format

# %%
df["Date of Joining"]=pd.to_datetime(df["Date of Joining"])

# %%
data_types=df.dtypes
print(data_types)
# Out:
# ID                          int64
# Age                         int64
# Income                    float64
# Height                    float64
# Credit Score              float64
# Dept                      float64
# Country                    object
# Occupation                 object
# Date of Joining    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Correct the Column Name from Dept to Debt

# %%
df.rename(columns={"Dept":"Debt"}, inplace=True)
df.head(5)
# Out:
#    ID  Age     Income  Height  Credit Score        Debt    Country Occupation  \
# 0   1   62    50000.0   193.0         509.0  488.563060         UK    Teacher
# 1   2   65  1000000.0   187.0         316.0  312.467648    Germany     Doctor
# 2   3   18   150000.0   178.0         406.0  387.337992  Australia     Artist
# 3   4   -2   200000.0   197.0         464.0  678.652685     France     Artist
# 4   5   21   200000.0   190.0         836.0  411.977741      Japan     Lawyer
#
#   Date of Joining
# 0      2023-07-14
# 1      2023-12-01
# 2      2022-06-20
# 3      2023-03-28
# 4      2022-05-19

# %% [markdown]
# ## Check for Invalid Entries
# Let's count how many negative values are in the columns

# %%
invalid_entries = df[df.select_dtypes(include='number') <0].count()

# %% [markdown]
# This takes a dataframe with selected numerical columns less than 0, and counts them

# %%
print("Invalid Entries:\n", invalid_entries)
# Out:
# Invalid Entries:
#  ID                 0
# Age                9
# Income             0
# Height             0
# Credit Score       0
# Debt               1
# Country            0
# Occupation         0
# Date of Joining    0
# dtype: int64

# %%
df[df.select_dtypes(include='number') <0]
# Out:
#     ID  Age  Income  Height  Credit Score  Debt Country Occupation  \
# 0  NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 1  NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 2  NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 3  NaN -2.0     NaN     NaN           NaN   NaN     NaN        NaN
# 4  NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# ..  ..  ...     ...     ...           ...   ...     ...        ...
# 95 NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 96 NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 97 NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 98 NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
# 99 NaN  NaN     NaN     NaN           NaN   NaN     NaN        NaN
#
#    Date of Joining
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ..             ...
# 95             NaT
# 96             NaT
# 97             NaT
# 98             NaT
# 99             NaT
#
# [100 rows x 9 columns]

# %% [markdown]
# So there are **9 values in Age** and **1 value in Dept** that comes out negative

# %% [markdown]
# ## Handle the Invalid Entries in the Categorical Variables

# %%
df["Country"].unique()
# Out:
# array(['UK', 'Germany', 'Australia', 'France', 'Japan', 'Canada', 'USA',
#        'U.S.', 'India'], dtype=object)

# %%
# Fix the Country Variable
df['Country']=df["Country"].replace({"U.S.":"USA"})

# %%
df["Country"].unique()
# Out:
# array(['UK', 'Germany', 'Australia', 'France', 'Japan', 'Canada', 'USA',
#        'India'], dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array(['Teacher', 'Doctor', 'Artist', 'Lawyer', 'Artxst', 'Engxneer',
#        'Nurse', 'Engineer', 'Docxor', 'Teaxher'], dtype=object)

# %%
#Fix the Mispelling in 'Occupation' Variable
occupation_corrections={"Artxst":"Artist",
                       "Docxor":"Doctor",
                       "Teaxher":"Teacher",
                       "Engxneer":"Engineer"}
df["Occupation"]=df["Occupation"].replace(occupation_corrections)

# %%
df["Occupation"].unique()
# Out:
# array(['Teacher', 'Doctor', 'Artist', 'Lawyer', 'Engineer', 'Nurse'],
#       dtype=object)

# %% [markdown]
# ## Check for Duplicate Records

# %%
duplicates=df.duplicated().sum()
print("Number of Duplicate Records: ", duplicates)
# Out:
# Number of Duplicate Records:  0

# %% [markdown]
# ### Removing Duplicate Records

# %%
df=df.drop_duplicates()

# %% [markdown]
# ## Check for Missing Data

# %%
missing_data=df.isnull().sum()
print("Missing data:\n", missing_data)
# Out:
# Missing data:
#  ID                  0
# Age                 0
# Income             20
# Height              5
# Credit Score        5
# Debt                0
# Country             0
# Occupation          0
# Date of Joining     0
# dtype: int64

# %% [markdown]
# *Look at data visualization to see how to visualize this*

# %% [markdown]
# # Handling and Cleaning Invalid Entries

# %% [markdown]
# ### Replacing Invalid Entries with NaN

# %%
#df.loc[df['Age']<0,'Age']=None
#df.loc[df['Dept']<0,'Dept']=None

# %%
invalid_entries = df[df.select_dtypes(include='number') <0].count()
print("Invalid Entries:\n", invalid_entries)
# Out:
# Invalid Entries:
#  ID                 0
# Age                0
# Income             0
# Height             0
# Credit Score       0
# Debt               1
# Country            0
# Occupation         0
# Date of Joining    0
# dtype: int64

# %% [markdown]
# ### Replacing Invalid Entries with Median/Mean (Uncommon)

# %%
invalid_entries = df[df.select_dtypes(include='number') <0].count()
print("Invalid Entries:\n", invalid_entries)
# Out:
# Invalid Entries:
#  ID                 0
# Age                0
# Income             0
# Height             0
# Credit Score       0
# Debt               1
# Country            0
# Occupation         0
# Date of Joining    0
# dtype: int64

# %%
median_age = df['Age'][df['Age']>=0].median()
df.loc[df['Age']<0,'Age']=median_age

# %%
median_age=df['Debt'][df['Debt']>=0].median()
df.loc[df['Debt']<0,'Debt']=median_age

# %%
invalid_entries = df[df.select_dtypes(include='number') <0].count()
print("Invalid Entries:\n", invalid_entries)
# Out:
# Invalid Entries:
#  ID                 0
# Age                0
# Income             0
# Height             0
# Credit Score       0
# Debt               0
# Country            0
# Occupation         0
# Date of Joining    0
# dtype: int64

# %% [markdown]
# ### Removing Invalid Data in Age

# %%
# Remove age more than 100 that are rare

df=df[df['Age']<=100]

# %% [markdown]
# # Initial Data Visualization

# %%
# Visualizing all columns in one code
for col in df.select_dtypes(include=['number']).columns:
    sns.histplot(df[col], kde=True)
    plt.title(f"Histogram and Density Plot of {col}")
    plt.show()

# %%
for col in df.select_dtypes(include=['number']).columns:
  sns.boxplot(x=df[col])
  plt.title(f"Box Plot of {col}")
  plt.show()

# %%
sns.pairplot(df.select_dtypes(include=['number']), kind='reg')
plt.suptitle("Pairwise Scatterplots of numberical variables")
plt.show()
# Out:
# /home/sarahesayas/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix=df.corr(numeric_only=True)
correlation_matrix
# Out:
#                     ID       Age    Income    Height  Credit Score      Debt
# ID            1.000000 -0.055518  0.083111  0.047481      0.038381  0.052806
# Age          -0.055518  1.000000  0.136303  0.091217     -0.095944  0.087118
# Income        0.083111  0.136303  1.000000  0.177368     -0.015597 -0.082635
# Height        0.047481  0.091217  0.177368  1.000000      0.032773  0.049909
# Credit Score  0.038381 -0.095944 -0.015597  0.032773      1.000000 -0.151442
# Debt          0.052806  0.087118 -0.082635  0.049909     -0.151442  1.000000

# %% [markdown]
# There's not really a strong correlation in any of these, the strongest would have to be between **Height** and **Income**, with a correlation of 0.17. **Age** and **Income**, have a correlation of 0.14

# %%
plt.figure(figsize=(20,12))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %%
# !pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: missingno in /home/sarahesayas/.local/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from missingno) (3.7.2)
# Requirement already satisfied: scipy in /home/sarahesayas/.local/lib/python3.10/site-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in /home/sarahesayas/.local/lib/python3.10/site-packages (from missingno) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->missingno) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->missingno) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import missingno as msno

msno.matrix(df)
plt.show()

# %%
missing_data=df.isnull().sum()
print("Missing data:\n", missing_data)
# Out:
# Missing data:
#  ID                  0
# Age                 0
# Income             16
# Height              4
# Credit Score        5
# Debt                0
# Country             0
# Occupation          0
# Date of Joining     0
# dtype: int64

# %% [markdown]
# ### Drop Missing Values

# %%
df.dropna(subset=["Income"], inplace=True)
df.dropna(subset=["Height"], inplace=True)
df.dropna(subset=["Credit Score"], inplace=True)
# Out:
# /tmp/ipykernel_8276/1411316156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["Income"], inplace=True)
# /tmp/ipykernel_8276/1411316156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["Height"], inplace=True)
# /tmp/ipykernel_8276/1411316156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["Credit Score"], inplace=True)
